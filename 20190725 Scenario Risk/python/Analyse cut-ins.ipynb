# %%
import os
import numpy as np
import json

# %%
filename = os.path.join("data", "5_cutin_scenarios", "cut_in_scenarios.json")

# %%
with open(filename, "r") as file:
    cutins = json.load(file)

# %%
lateral_activities = []
longitudinal_activities = []
for cutin in cutins:
    # Get ID of actor that is not the ego vehicle.
    actor_id = next((actor["id"] for actor in cutin["actor"] 
                     if "EgoVehicle" not in actor["tag"]))
    lat = []
    lon = []
# Out:
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# ...

# %%
np.unique([len(cutin["activity"]) for cutin in cutins], return_counts=True)
# Out:
# (array([4, 5, 6]), array([401,  18,   5], dtype=int64))

# %%
q, w = [], []
for cutin in cutins:
    if len(cutin["activity"]) == 4:
        q.append(np.unique([x["tstart"] for x in cutin["activity"]]))
        w.append(np.unique([x["tend"] for x in cutin["activity"]]))

# %%
for e in w:
    if len(e) > 1:
        print(np.diff(e))
# Out:
# [0.3499999]
# [0.8499999]
# [0.70000005]
# [0.54999995]
# [0.5]
# [1.]
# [0.04999995]
# [0.1500001]
# [0.20000005]
